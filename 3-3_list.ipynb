# %% [markdown]
# # 리스트 자료형

# %%
odd=[1,3,5,7,9]
even=[2,4,6,8,10]
print(odd,even)
# Out:
# [1, 3, 5, 7, 9] [2, 4, 6, 8, 10]

# %%
# 빈 리스트
A = []
A
# Out:
# []

# %%
a=list()
a
# Out:
# []

# %%
b = [1,2,3]
c = ["life", 'is', 'short']
d = [1,2,'life','is']
e = [1,2,['life','is']]

# %%
len(e)
# Out:
# 3

# %% [markdown]
# ## 1. 리스트의 인덱싱과 슬라이싱

# %%
a =[1,2,3]
a
# Out:
# [1, 2, 3]

# %%
a[0:2],a[0:3],a[-1:] ,
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 a[0:2],a[0:3],a[-1:] ,a[0]+a[3]
#
# IndexError: list index out of range

# %%
a[0] + a[2]
# Out:
# 4

# %%
a= [1,2,3,['a','b','c']]
a
# Out:
# [1, 2, 3, ['a', 'b', 'c']]

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[3][2]
# Out:
# 'c'

# %%
a[-1][-1]
# Out:
# 'c'

# %%
a = [1,2,3,4,5]
a[:3]
# Out:
# [1, 2, 3]

# %%
a[-2:]
# Out:
# [4, 5]

# %%
a = [1,2,3,['a','b','c'],4,5]
a[2:5]
# Out:
# [3, ['a', 'b', 'c'], 4]

# %%
a[3][1:]
# Out:
# ['b', 'c']

# %% [markdown]
# ## 2.리스트 연산하기

# %% [markdown]
# ### 리스트 더하기(+)

# %%
a = [1,2,3]
b = [4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### 리스트 반복하기(*)

# %%
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a*3+b
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### 리스트 길이 구하기 :len()

# %%
len(a*3)
# Out:
# 9

# %%
a = [1,2,3,['a','b','c'],4,5]
len(a)
# Out:
# 6

# %%
len(a[3])
# Out:
# 3

# %% [markdown]
# ### 초보자가 범하기 쉬운 리스트 연산 오류 (정수와 문자열을 서로 더할 수 없음.)

# %%
a=[1,2,3]

# %%
a[3]+hi
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 a[3]+hi
#
# IndexError: list index out of range

# %%
str(a[2])
# Out:
# '3'

# %%
str(a[2])+'hi'
# Out:
# '3hi'

# %% [markdown]
# ### 3.리스트의 수정과 삭제

# %%
a = [1,2,3]

# %%
a[2] = 4

# %%
a
# Out:
# [1, 2, 4]

# %%
# del 키워드로 리스트 요소 삭제
del a[1]

# %%
a
# Out:
# [1, 2]

# %%
a = [1,2,3,4,5]
del a[-2:]
a
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 4. 리스트 관련 함수

# %% [markdown]
# 리스트에 요소 추가 : apppend(value)

# %%
a= [1,2,3]
a.append('four')
a
# Out:
# [1, 2, 3, 'four']

# %%
a.append([5,6])
a
# Out:
# [1, 2, 3, 'four', [5, 6], [5, 6]]

# %% [markdown]
# 리스트 정렬 : sort()

# %%
a = [3,7,5,1,4]
a.sort()
a
# Out:
# [1, 3, 4, 5, 7]

# %%
a = ['a','d','e','c','b']
a.sort()
a
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
a.sort( reverse=True )
a
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
list(reversed(a))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# 리스트 뒤집기(index 역순 정렬) :reavered()

# %%
a = ['a','d','e','c','b']
a.reverse()
a
# Out:
# ['b', 'c', 'e', 'd', 'a']

# %% [markdown]
# 인덱스 반환 : index(value)

# %%
a.index("c")
# Out:
# 1

# %%
a.count('e')
# Out:
# 1

# %%
a.index('f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 a.index('f')
#
# ValueError: 'f' is not in list

# %% [markdown]
# 리스트에 요소 삽입 : insert(index,value)

# %%
a = [1,2,3]
a.insert(0,4)

# %%
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)

# %%
a
# Out:
# [4, 1, 2, 5, 3]

# %% [markdown]
# 리스트 요소 제거 : remove(value)

# %%
a = ['a','d','e','c','b']
a.remove("a")

# %%
a
# Out:
# ['d', 'e', 'c', 'b']

# %%
a = ['a','a','a','b','c','c','b']
a.remove('a')
a
# Out:
# ['a', 'a', 'b', 'c', 'c', 'b']

# %% [markdown]
# 리스트 요소 끄집어 내기 : .pop(index)

# %%
a.pop(1)
a
# Out:
# ['a', 'c', 'b']

# %%
a.pop(0)
a
# Out:
# ['b']

# %% [markdown]
# 리스트에 포함된 요소 x의 개수 세기 : .count(value)

# %%
a = [1,2,3,1,1,1,]
a.count(1)
# Out:
# 4

# %% [markdown]
# 리스트 확장 : .extend(value)

# %%
a=[1,2,3]
a.extend([4,5,6])
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b=[4,5,6]
a.extend([b])
a
# Out:
# [1, 2, 3, 4, 5, 6, [4, 5, 6]]

# %%
a.extend((30,[4,5]))
a
# Out:
# [1, 2, 3, 4, 5, 6, [4, 5, 6], 30, [4, 5]]

# %%
a=[1,2,3]
a+=[4,5]
a
# Out:
# [1, 2, 3, 4, 5]
