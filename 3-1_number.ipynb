# %% [markdown]
# # 1. 숫자형은 어떻게 만들고 사용할까?

# %%
a
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
print(a * 2)
# Out:
# 246

# %%
a= -178

# %%
print(a)
# Out:
# -178

# %%
b= 178

# %%
print(a * b)
# Out:
# -31684

# %%
a= 0
a
# Out:
# 0

# %%
a= 1.2

# %%
a
# Out:
# 1.2

# %%
a= -3.45

# %%
a
# Out:
# -3.45

# %%
a=4.24E10
a
# Out:
# 42400000000.0

# %%
a=4.24e-10

# %%
a
# Out:
# 4.24e-10

# %%
print(f"{a:.10f}")
# Out:
# 0.0000000004

# %%
a= 0o123

# %%
a
# Out:
# 83

# %%
a= 0x8fff
a
# Out:
# 36863

# %%
b=0x123411
b
# Out:
# 1192977

# %%
a = 3 
b = 4
a + b 
a * b
# Out:
# 12

# %% [markdown]
# # 2. 숫자를 활용하기 위한 연산자

# %% [markdown]
#  # 사칙연산

# %%
a=3 
b=4

# %%
a+b
# Out:
# 7

# %%
a - b
# Out:
# -1

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.75

# %% [markdown]
# # 제곱(**) 연산자

# %%
a ** b
# Out:
# 81

# %% [markdown]
# # 나머지(%) 연산자

# %%
a % b
# Out:
# 3

# %%
b % a
# Out:
# 1

# %% [markdown]
#  # 몫(//) 연산자

# %%
7//3
# Out:
# 2

# %%
3//7
# Out:
# 0

# %%
7//4
# Out:
# 1

# %%
a= "life is too short, You need python"
b= "python is good"

# %%
a+b
# Out:
# 'life is too short, You need pythonpython is good'

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'str'
