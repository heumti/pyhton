# %% [markdown]
# #불 자료형

# %% [markdown]
# ## 1. 불 자료형은 어떻게 사용할까 ?

# %%
# 변수에 볼 자료형 지정
a = True
a
# Out:
# True

# %%
b = False
b
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
1==1
# Out:
# True

# %%
2>1
# Out:
# True

# %%
2<1
# Out:
# False

# %%
1 == 2
# Out:
# False

# %% [markdown]
# ## 2. 자료형의 참과 거짓

# %% [markdown]
# 자료형의 참과 거짓이 프로그램에서 어떻게 쓰이는지 간단히 알아보자.

# %%
a = [1,2,3,4]
while a:
    print(a.pop())
    a
# Out:
# 4
# 3
# 2
# 1

# %%
if[1,2] : 
    print('참')
else :
    print('거짓')
# Out:
# 참

# %% [markdown]
# ## 3. 불연산

# %%
bool("python")
# Out:
# True

# %%
bool([1,2,3])
# Out:
# True

# %%
bool(0)
# Out:
# False
