# %%
print(type('안녕하세요'))
# Out:
# <class 'str'>

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print('이름\t나이\t지역')
print('윤인성\t25\t서울')
# Out:
# 이름	나이	지역
# 윤인성	25	서울

# %%
print("\\ \\ \\ \\ ")
# Out:
# \ \ \ \

# %%
print("문자 선택 연산자에 대해 알아볼까요?")
print("안녕하세요"[0])
# Out:
# 문자 선택 연산자에 대해 알아볼까요?
# 안

# %%
print("안녕하세요"[1:4])
# Out:
# 녕하세

# %%
print('안녕하세요'[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print('안녕하세요'[10])
#
# IndexError: string index out of range

# %%
print(len("안녕하세요"))
# Out:
# 5

# %%
print(273)
print(52.273)
# Out:
# 273
# 52.273

# %%
print("안녕" +"하세요"*3)
# Out:
# 안녕하세요하세요하세요

# %%
print(("안녕"+'하세요')*3)
# Out:
# 안녕하세요안녕하세요안녕하세요

# %%
pi= 3.141592265

# %%
pi
# Out:
# 3.141592265

# %%
r = 10 
print(2*pi*r)
# Out:
# 62.8318453

# %%
print(pi*r*r)
# Out:
# 314.1592265

# %%
number= 100
number+= 10
number += 20
print("number:",number)
# Out:
# number: 130

# %%
string_a = input("입력A> ")
int_a = int(string_a)

string_b = input("입력B> ")
int_b = int(string_b) 

print("문자열 자료:", string_a + string_b)
print("숫자 자료:", int_a + int_b)
# Out:
# 문자열 자료: 27352
# 숫자 자료: 325

# %%
age = 25
negative_num = -10

pi =3.141592
height = 175.5

print(type(age))
print(type(pi))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(10>5)
# Out:
# True

# %%
is_student = True
is_adult = False
print(is_student)
# Out:
# True

# %%
fruits = ["사과",'오렌지','수박']
fruits.append("참외")
fruits[0]
print(fruits)
print(type(fruits))
# Out:
# ['사과', '오렌지', '수박', '참외']
# <class 'list'>

# %%
coordinates =(37.5665 , 126.9780)
print(coordinates[1])
print(type(coordinates))
# Out:
# 126.978
# <class 'tuple'>

# %%
user_info ={"name": "김철수" , "age" : 25 ,"city" : "서울"}

print(user_info["name"])
user_info["job"] = "개발자"
print(user_info)
# Out:
# 김철수
# {'name': '김철수', 'age': 25, 'city': '서울', 'job': '개발자'}
